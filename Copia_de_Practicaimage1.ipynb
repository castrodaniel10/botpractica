# %% [markdown]
# <a href="https://colab.research.google.com/github/castrodaniel10/botpractica/blob/master/Copia_de_Practicaimage1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as nop
from scipy import misc
import matplotlib.pyplot as plt
import urllib.request
from PIL import Image

plt.style.use("dark_background")

# %%
url="https://lh3.googleusercontent.com/KjC39gbiQCnZo9Vxk16tx32btbAFcgFQzGIdd8Hsx4yr31hC2MYYn6s6gzy4_Wj80JYMdbnJllrTDrr1t-AyGaQTXDItCpy3no4_LTjPYXdDX86aTmXvQ0QLYx8eoAn-pEKI1CTTp1-r4OvF7bwlPOWUCql1JIhZs_KjnSvWZ89K145IfuP8rZbDgGxkqtX2rNP4TC_M3JP0ym9LFH-N5M23IQArKLLIaCob3VrUQvbpNety3_TBysWlWygNFlje8RCtqYIiadKrJXABESph0m6DzQddgo1N29lkWLYF65w6AaRhg3tnWcmWJdC1AhPE0AE8KvBFVV9TbpCoNYURg9b2h23Aauy0q4UZttnMlfcc6asJ27L0-KNDCuT2VHISHqNy4_ULyTHbdL9Q30kU2tgmbVqav18FDD5vgRXetMlOO4OaVEvN6mwIHGEgy88G-qa5QBwWzUArypsyH5pkGKJBawR6mVGNAcUPaLe_ZD9HpfrUhI1GLP_od_9i27Tr9vsz6b-JcjSAW74Tq8g54T3e3ASDFgzptoxIppEUXgy8OGXztD7MTqqMKq5HaS6CgAmOEABO-QfzQaILwtvdU6Na_JMOG9P8XoHMcChEFlnRLgQo6sihiqd7Lu2MKUiD7QHjrvJ7kHRChxrLG10G6eqQgtufXB8LyZ5dnOaUsItFyFy_5jWqj7X3JyoErQ=w871-h653-no"
internet_image=Image.open(urllib.request.urlopen(url))

# %%
image1=nop.array(internet_image)
image2=nop.array(internet_image)
image3=nop.array(internet_image)
image4=nop.array(internet_image)

# %%
plt.imshow(image1)

# %%
print(image1.shape)
653*871*3
# Out:
# (653, 871, 3)
# 1706289

# %%
print (nop.amin(image1), nop.amax(image1))
# Out:
# 0 255

# %%
print("Fila Completa")
print(image1[150])
print("____________________________________________")
print("")
# Out:
# Fila Completa
# [[140 162 176]
#  [140 162 176]
#  [140 162 176]
#  ...
#  [127 161 189]
#  [127 161 189]
#  [130 164 192]]
# ____________________________________________

# %%
print("Columna completa")
print(image1[:,150])
print("__________________________________")
# Out:
# Columna completa
# [[150 169 186]
#  [151 170 187]
#  [152 171 188]
#  ...
#  [ 80  98  56]
#  [ 70  89  44]
#  [ 58  80  34]]
# __________________________________

# %%
print("")
print("3 colores de un pixel")
print(image1[150,150,0])
print("_____________________________________")
# Out:
# 3 colores de un pixel
# 155
# _____________________________________

# %%
image2[100:250,:,0]=255
image2[300:450,:,1]=255
image2[500:650,100:1000,2]=255
plt.figure(figsize=(10,20))
plt.imshow(image2)

# %%
filtro = image3 < 150
print(filtro.shape)
print(image3.shape)
plt.imshow(image3)
# Out:
# (653, 871, 3)
# (653, 871, 3)

# %%
image3[filtro]=0
plt.figure(figsize=(10,20))
plt.imshow(image3)

# %%
filtro = image4 > 150
print(filtro.shape)
print(image4.shape)
plt.imshow(image4)
# Out:
# (653, 871, 3)
# (653, 871, 3)

# %%
image4[filtro]=255
plt.figure(figsize=(10,20))
plt.imshow(image4)
